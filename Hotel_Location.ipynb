# %%
# !pip install reverse_geocoder
# Out:
# ...
#      |████████████████████████████████| 2.2 MB 1.8 MB/s eta 0:00:01
# ...
#   Created wheel for reverse-geocoder: filename=reverse_geocoder-1.5.1-py3-none-any.whl size=2268088 sha256=15d751f808fc459aadb1ec9a289a59abd8fbb025ba7a9c18f52223485447bac6
#   Stored in directory: /Users/vikasbharadwaj/Library/Caches/pip/wheels/65/42/5e/223fcd5dc869ff98d5ee6b19e236f82828e4e3c039328ebe20
# Successfully built reverse-geocoder
# ...

# %%
# !pip install pprint
# Out:
# ERROR: Could not find a version that satisfies the requirement pprint (from versions: none)
# ERROR: No matching distribution found for pprint

# %%
import reverse_geocoder as rg 
import pprint

# %%
def reverseGeocode(coordinates): 
    result = rg.search(coordinates) 
      
    # result is a list containing ordered dictionary. 
    pprint.pprint(result)

# %%
# # Driver function 
# if __name__=="__main__": 
      
#     # Coorinates tuple.Can contain more than one pair. 
coordinates =(54.11426909054315, 17.95467395999626) 
reverseGeocode(coordinates)
# Out:
# Loading formatted geocoded file...
# [{'admin1': 'Pomeranian Voivodeship',
#   'admin2': 'Powiat koscierski',
#   'cc': 'PL',
#   'lat': '54.12226',
#   'lon': '17.98119',
#   'name': 'Koscierzyna'}]

# %% [markdown]
# #Lat Longs from Name and Address

# %%
# !pip install geopy
# Out:
# ...
#      |████████████████████████████████| 112 kB 2.1 MB/s eta 0:00:01
# ...

# %%
# #USe Case: Lets check Ibis Hotel in Essen,Germany
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="HRS")
location = geolocator.geocode("Hof von Hannover	")

# %%
print(location.address)
print(location.latitude)
print(location.longitude)

# print(location.raw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-81d12c989a30> in <module>
# ----> 1 print(location.address)
#       2 print(location.latitude)
#       3 print(location.longitude)
#       4
#       5 # print(location.raw)
#
# NameError: name 'location' is not defined

# %%
pip install geocoder
# Out:
# ...
#      |████████████████████████████████| 98 kB 1.6 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# from geopy.geocoders import Nominatim
# geolocator = Nominatim()
# location = geolocator.reverse("22.5757344, 88.4048656")
# print(location.address)
# print((location.latitude, location.longitude))

# %%
# from geopy.geocoders import GoogleV3

# geolocator = GoogleV3(api_key=google_key)
# locations = geolocator.reverse("22.5757344, 88.4048656")
# if locations:
#     print(locations[0].address)  # select first location
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-d774f47e039b> in <module>
# ----> 1 from geopy.geocoders import GoogleV3
#       2
#       3 geolocator = GoogleV3(api_key=google_key)
#       4 locations = geolocator.reverse("22.5757344, 88.4048656")
#       5 if locations:
#
# ModuleNotFoundError: No module named 'geopy'

# %% [markdown]
# # LOOP for finding Hotel Address using Hotel Street.

# %%
#data
import pandas as pd

# %%
data = pd.read_excel("/Users/vikasbharadwaj/Downloads/HRS_data_package/hotel_ENC_dataxlsx.xlsx")

# %%
data.head()
# Out:
#    HOTEL_ID                          HOTEL_NAME              HOTEL_STREET  \
# 0         1                        Savoy Berlin          Fasanenstr. 9-10
# 1         5  Mercure Airport Hotel Berlin Tegel  Kurt Schumacher Damm 202
# 2         6      Mercure Hotel Berlin City West           Ohmstrasse  4-6
# 3         7         Pullman Berlin Schweizerhof     Budapester Strasse 25
# 4         9         Hotel Birke, Ringhotel Kiel           Martenshofweg 8
#
#   HOTEL_ZIP_CODE  HOTEL_LATITUDE  HOTEL_LONGITUDE            HOTEL_CITY_NAME  \
# 0          10623       52.506178        13.327693            Berlin (Berlin)
# 1          13405       52.551593        13.301396            Berlin (Berlin)
# 2          13629       52.536032        13.273297            Berlin (Berlin)
# 3          10787       52.506315        13.344326            Berlin (Berlin)
# 4          24109       54.317142        10.070878  Kiel (Schleswig-Holstein)
#
# ...

# %%
data1 = data[['HOTEL_NAME','HOTEL_STREET','HOTEL_LATITUDE','HOTEL_LONGITUDE']]

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Do not run this code again else it will change the sample data.

# %%
#take sample
sample = data1.sample(frac=0.05)

# %%
sample
# Out:
#                                               HOTEL_NAME  \
# 5365   The Originals Boutique, Hôtel Rueil La Défense...
# 306                             M&A Cityhotel Hildesheim
# 11211                       EFC Oumei Service Apartmentf
# 1002                                            Days Inn
# 2165                             Aparthotel am Heidensee
# ...                                                  ...
# 10335                                  Hotel Expresso R1
# 3544                                     Scandic Sjølyst
# 2170                                         Dünenschloß
# 11375                                      Amts-Apotheke
# 6548                              Royal Boutique Savassi
#
#                                             HOTEL_STREET  HOTEL_LATITUDE  \
# 5365                                 20, avenue Albert 1       48.881570
# 306                                    Hindenburgplatz 6       52.149614
# ...

# %%
loca = geolocator.geocode("Ul. Tadeusza Kosciuszki 17, 83-400")
la = loca.latitude
lo = loca.longitude
print(la)
print(lo)
# Out:
# 54.1859619
# 15.5891778

# %%
result = []
lat = []
long = []
for col in sample['HOTEL_NAME']:
    time.sleep(2)
    try:
        location1 = geolocator.geocode(col, timeout=None)
        combined = location1.address
        lati = location1.latitude
        longi = location1.longitude
        print(lati)
        print(longi)
        result.append(combined)
        lat.append(lati)
        long.append(longi)
        

    except AttributeError:
        a = print("Faulty Location")
        result.append(a) 
        lat.append(a) 
        long.append(a)
        pass
# Out:
# Faulty Location
# Faulty Location
# Faulty Location
# Days Inn and Suites Tempe, 1600, West Elliot Road, Tempe, Maricopa County, Arizona, 85284, United States
# [None, None, None]
# [None, None, None]
# Faulty Location
# Van der Valk Hotel Zaltbommel-A2, 65, Hogeweg, Zaltbommel, Gelderland, Nederland, 5301LJ, Nederland
# [None, None, None, 33.349952, None]
# [None, None, None, -111.96554555105016, None]
# Landhotel Rügen, 2A, Stönkvitz, Samtens, West-Rügen, Vorpommern-Rügen, Mecklenburg-Vorpommern, 18573, Deutschland
# [None, None, None, 33.349952, None, 51.7956088]
# [None, None, None, -111.96554555105016, None, 5.2544827]
# Pockinger Hof, 13, Klosterstraße, Wolfing, Pocking, Landkreis Passau, Bayern, 94060, Deutschland
# [None, None, None, 33.349952, None, 51.7956088, 54.3743737]
# [None, None, None, -111.96554555105016, None, 5.2544827, 13.3376199]
# Faulty Location
# Familienhotel, 8, Seifengasse, Altstadt, Weimar, Thüringen, 99423, Deutschland
# ...

# %%
sample['generated_address'] = result
sample['generated_latitude'] = lat
sample [ 'generated_longitude'] = long

# %%
sample.to_csv("Hotel Name with Address1.csv")

# %% [markdown]
# # Using Google Maps API for gathering location data.

# %%
def Locate(det):
    dets = det['results']
    lat = ''
    long = ''
    if len(dets) >= 1:
        det1 = dets[0]
        loc = det1['geometry']
        latlong = loc['location']
        lat = str(latlong['lat'])
        long = str(latlong['lng'])
#    if len(dets) == 2:
#        det = dets[1]
#        loc = det['geometry']
#        latlong = loc['location']
#        lat = lat+' '+str(latlong['lat'])
#        long = long+' '+str(latlong['lng'])
#    if len(dets) >= 3:
#        det = dets[2]
#        loc = det['geometry']
#        latlong = loc['location']
#        lat = lat+' '+str(latlong['lat'])
#        long = long+' '+str(latlong['lng'])
    return lat,long

# %% [markdown]
# Query using Google Maps API key in URL to read JSON response containing location data

# %%
names = sample['HOTEL_NAME']
i= 0
lat3 = []
long3 = []
for name in names:
    URL_query = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query='+name+'&key=AIzaSyBzWzNqgcPObNCiheMFki1FuDEU3cY5bL0'
    r = requests.get(URL_query)
    latit,longit = Locate(r.json())
    lat3.append(latit)
    long3.append(longit)
    i = i+1
    if i%100 == 0:
        print(i)
    time.sleep(2)

# %%
sample1.to_csv("Hotel Loc.csv")

# %% [markdown]
# # USING  HOTEL STREET

# %%
#take sample for hotel street & see if we are getting right names
# data2 = data[['HOTEL_NAME',"HOTEL_STREET",'HOTEL_LATITUDE','HOTEL_LONGITUDE']]

# %%
#take sample
# sample2 = data2.sample(frac=0.07)

# %%
# sample2
# Out:
#                                               HOTEL_NAME  \
# 9319                               Herrnbrod & Ständecke
# 1587                         ibis Styles Bremen Altstadt
# 11625  Atour Hotel Hangzhou Future Technology City Ha...
# 7399                                              Europa
# 1854                               Oriente Atiram Hotels
# ...                                                  ...
# 2515                                Göbels Sophien-Hotel
# 1656                                 Parkhotel Surenburg
# 8056                                       Bären Gasthof
# 2294                                     Amari Watergate
# 8009                          Friendly Cityhotel Oktopus
#
#                                          HOTEL_STREET  HOTEL_LATITUDE  \
# 9319                                  Hauptstr. 29-33       50.017060
# 1587                                 Faulenstrasse 45       53.080692
# ...

# %% [markdown]
# # Only Run the Lines Below

# %%
import time

# %%
result2 = []
lat2 = []
long2 = []
for col in sample['HOTEL_STREET']:
    time.sleep(6)
    try:
        location = geolocator.geocode(col, timeout = None)
        combined = location.address
        lat1 = location.latitude
        long1 = location.longitude
        print(combined)
        print(lat1)
        print(long1)
        result2.append(combined)
        lat2.append(lat1)
        long2.append(long1)
        

    except AttributeError:
        a = print("Faulty Location")
        result2.append(a)
        lat2.append(a)
        long2.append(a)
        pass
# Out:
# Avenue Albert I, Enghien, Ath, Hainaut, Wallonie, 7850, België / Belgique / Belgien
# 50.6931367
# 4.0405201
# Architektenkammer Rheinland-Pfalz, 6, Hindenburgplatz, Neustadt, Mainz, Rheinland-Pfalz, 55118, Deutschland
# 50.006491499999996
# 8.264064960762521
# Faulty Location
# Provinzialstraße, Unna, Kreis Unna, Nordrhein-Westfalen, 59427, Deutschland
# 51.5230802
# 7.6456956
# 19, Buchenweg, Hüngheim, Ravenstein, Verwaltungsverband Osterburken, Neckar-Odenwald-Kreis, Baden-Württemberg, 74747, Deutschland
# 49.40251375
# 9.507095635380372
# 65, Hogeweg, Offem Zuid, Noordwijk-Binnen, Noordwijk, Zuid-Holland, Nederland, 2201AN, Nederland
# 52.2286381
# 4.449428
# An der B96, Alt Lancken, Sassnitz, Vorpommern-Rügen, Mecklenburg-Vorpommern, 18546, Deutschland
# 54.5150581
# 13.6063224
# 13, Klosterstraße, Wilhelm-Pieck-Siedlung, Lutherstadt Eisleben, Mansfeld-Südharz, Sachsen-Anhalt, 06295, Deutschland
# 51.5298954
# 11.5508178
# ...

# %%
sample2 = sample.copy

# %%
sample['generated_address1'] = result2
sample['generated_latitude1'] = lat2
sample['generated_longitude1'] = long2

# %%
sample.to_csv("Hotel Street with Address.csv")

# %%
sample2
# Out:
#                                              HOTEL_NAME  \
# 9605                                          Kaiserhof
# 8145                           SpringHill Suites Fresno
# 8005                                   Blu Hotel Brixia
# 11832                   Atour Hotel Xuzhou Suning Plaza
# 5001                 Hampton Inn Atlanta-Stone Mountain
# 5443                                       Viva Bröckel
# 9352                                             aDLERS
# 4230                                  Hotel Postgaarden
# 6044                                            Miramar
# 1269   Austria Trend Hotel Schloss Wilhelminenberg Wien
# 11655                          Augsburg Hotel Sonnenhof
# 10825                          Hampton Inn El Centro CA
#
#                           HOTEL_STREET  \
# 9605              Hannoversche Str. 29
# 8145         6844 North Fresno Street
# 8005             Via Sandro Pertini 10
# 11832         No.219 East Jianguo Road
# ...
